# %%
# !pip install -i https://test.pypi.org/simple/ whatsapp-chat-analyser
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: whatsapp-chat-analyser in /Users/aishwaryasingh/opt/anaconda3/lib/python3.8/site-packages (0.0.2)

# %%
#importing required libraries
import author
import chat
import whatsapp_text_cleaner as wtc
import whatsapp_chat_visualizer as wcv

import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/aishwaryasingh/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aishwaryasingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# This is how the text file would be looking right now.  << add image here

# %%
#loading the text file for analysis
# this cleans the text file and returns a structured dataframe
df = wtc.load_clean_dataframe('WhatsApp Chat with UW MSDS Fall21.txt')
df.head()
# Out:
#         Date      Time                  Author  \
# 0 2020-03-06  12:03 am                    None
# 1 2020-03-07   9:23 pm            Khirod Sahoo
# 2 2020-03-07   9:24 pm            Khirod Sahoo
# 3 2020-03-07   9:34 pm  Utkarsh Sharma Uw MSDS
# 4 2020-03-07   9:35 pm            Khirod Sahoo
#
#                                              Message Hours
# 0       You created group "UWash MSDS Fall20 admits"     0
# 1                                         Hi Utkarsh    21
# 2  You have any idea what would be the i20 amount...    21
# 3                                              55635    21
# 4                  Have some doubts..can I call you?    21

# %% [markdown]
# # Data Visualization

# %%
wcv.bar_plot(df,max=5,sort=False) # check the main file to understand what is this error?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c99eb39c8210> in <module>
# ----> 1 wcv.bar_plot(df,max=5,sort=False)
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/whatsapp_chat_visualizer.py in bar_plot(df, title, max, sort)
#      49
#      50     for i, v in enumerate(df.iloc[:,1]):
# ---> 51         axes.text(v + v/100, i , str(v), color=bars[0].get_facecolor(), fontweight='bold')
#      52     plt.show()
#      53
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
explode=[0.1,0,0.1,0.2,0.4]
wcv.pie(df,max=5, explode = explode)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-183a6e6b6fc1> in <module>
#       1 explode=[0.1,0,0.1,0.2,0.4]
# ----> 2 wcv.pie(df,max=5, explode = explode)
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/whatsapp_chat_visualizer.py in pie(df, explode, title, max, sort)
#      67     # only "explode" the 2nd slice (i.e. 'Hogs')
#      68     fig1, ax1 = plt.subplots()
# ---> 69     ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
#      70     ax1.axis('equal')  # Equal aspect ratio to ensure pie is a circle
#      71     plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    2993         # The use of float32 is "historical", but can't be changed without
#    2994         # regenerating the test baselines.
# -> 2995         x = np.asarray(x, np.float32)
#    2996         if x.ndim > 1:
#    2997             raise ValueError("x must be 1D")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __array__(self, dtype)
#     766               dtype='datetime64[ns]')
#     767         """
# --> 768         return np.asarray(self.array, dtype)
#     769
#     770     # ----------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     201
#     202     def __array__(self, dtype=None) -> np.ndarray:
# --> 203         return np.asarray(self._ndarray, dtype=dtype)
#     204
#     205     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '9:56 am'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-183a6e6b6fc1> in <module>
#       1 explode=[0.1,0,0.1,0.2,0.4]
# ----> 2 wcv.pie(df,max=5, explode = explode)
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/whatsapp_chat_visualizer.py in pie(df, explode, title, max, sort)
#      67     # only "explode" the 2nd slice (i.e. 'Hogs')
#      68     fig1, ax1 = plt.subplots()
# ---> 69     ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
#      70     ax1.axis('equal')  # Equal aspect ratio to ensure pie is a circle
#      71     plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    2993         # The use of float32 is "historical", but can't be changed without
#    2994         # regenerating the test baselines.
# -> 2995         x = np.asarray(x, np.float32)
#    2996         if x.ndim > 1:
#    2997             raise ValueError("x must be 1D")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __array__(self, dtype)
#     766               dtype='datetime64[ns]')
#     767         """
# --> 768         return np.asarray(self.array, dtype)
#     769
#     770     # ----------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     201
#     202     def __array__(self, dtype=None) -> np.ndarray:
# --> 203         return np.asarray(self._ndarray, dtype=dtype)
#     204
#     205     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '9:56 am'

# %%
# creating class for author and chat
A = author.Author()
C = chat.Chat()

# %%
# populating class attributes
A.update_info(df)
C.update_info(df)

# %% [markdown]
# ### Author related functions that you can use
# A.get_aggressiveness
# A.get_author_text_info
# A.get_consistency
# A.get_frequency
# A.get_letters_words
# A.get_metrics
# A.get_number_activeDays
# A.get_number_daysInGroup
# A.get_number_deletedMessges
# A.get_number_mediasShared
# A.get_number_textMessages
# A.get_startDate_endDate
# A.get_stats

# %%
print("hello user")
import author
import chat
import whatsapp_text_cleaner as wtc
import warnings
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import set_matplotlib_formats
warnings.filterwarnings("ignore")
import nltk
import whatsapp_chat_visualizer as wcv
explode=[0.1,0,0.1,0.2,0.4]
#nltk.data.path.append('/Users/stlp/Downloads/')
extra_StopWords = ["thats","dont","<Media omitted>","media","Media","Omitted","omitted","also","like","https","from","all","also","and","any","are","but","can","cant","cry","due","etc","few","for","get","had","has","hasnt","have","her","here","hers","herself","him","himself","his","how","inc","into","its","ltd","may","nor","not","now","off","once","one","only","onto","our","ours","out","over","own","part","per","put","see","seem","she","than","that","the","their","them","then","thence","there","these","they","this","those","though","thus","too","top","upon","very","via","was","were","what","when","which","while","who","whoever","whom","whose","why","will","with","within","without","would","yet","you","your","yours","the"]
filepath='WhatsApp Chat with UW MSDS Fall21.txt'
text_df=wtc.load_clean_dataframe(filepath)
A=author.Author()
C=chat.Chat()
A.update_info(text_df)
C.update_info(text_df)
#author_buffer_details=pd.DataFrame(data=A.name,columns=['Author'])
#author_buffer_details=author_buffer_details.merge(A.get_number_activeDays(text_df),on='Author',how='left')
#df_days_texted=pd.DataFrame(text_df.groupby('Author')['Date'].nunique()).rename(columns={'Date':'Days_texted'})
#df=A.get_metrics(text_df)
df_new=A.remove_null_authors(text_df)
df=A.get_frequency(text_df)

print(df)
wcv.bar_plot(df,max=5,sort=False)
wcv.pie(df,max=5,explode=explode)
df=A.get_author_text_info(df_new,extra_StopWords,wordCloud=True)
print(df.head())
print("code ran succesfully")
# Out:
# hello user
# Number of messages per day on whatsapp since the start date
#                      Author   Frequency
# 26          +91 83101 79085  120.000000
# 28          +91 98196 02059   57.000000
# 32          +91 81787 41993   50.000000
# 33          +91 76660 66985   21.000000
# 44         Kirsteen NG Msds    2.833333
# 41                Anagha UW    2.428571
# 20          +91 98211 63479    0.731092
# 17          Amrit Bhat MSDS    0.442177
# 40     Reeya Pimple Uw Msds    0.367347
# 3   Abhinav Thakur Uw Admit    0.281046
# 22          +91 88846 04504    0.250000
# 1              Khirod Sahoo    0.201058
# 10  Ananya Sharma UW Admits    0.132576
# 4           +91 99690 86610    0.121429
# 14          +91 70931 74555    0.100000
# 19          +91 95828 44965    0.090909
# 5           +91 84518 92599    0.049270
# 12          +91 99232 23065    0.042683
# 0                      None         NaN
# 2    Utkarsh Sharma Uw MSDS         NaN
# 6           +91 80877 44932         NaN
# 7           +91 96198 81901         NaN
# 8         Aniket Fadia MSDS         NaN
# 9        Aamir Darukhanwala         NaN
# 11          +91 96867 61942         NaN
# 13          +91 90101 38928         NaN
# 15     Shweta Mayekar Uwash         NaN
# 16          +91 94820 11876         NaN
# 18          +91 97397 61811         NaN
# 21          Aishwarya Uwash         NaN
# 23          +91 94047 96323         NaN
# 24          +91 98332 55430         NaN
# 25          +91 81970 59012         NaN
# 27          +91 78270 62118         NaN
# 29          +91 98222 70678         NaN
# 30          +91 99204 38945         NaN
# 31          +91 96770 66394         NaN
# 34          +91 89750 58874         NaN
# 35          +91 85276 57878         NaN
# 36          +91 90434 21357         NaN
# 37          +91 87900 41485         NaN
# 38         Tarun Reddy MSDS         NaN
# 39          +91 88678 42245         NaN
# 42            Anushka Patil         NaN
# 43           Ernesto Cedial         NaN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b611cfa143b5> in <module>
#      29 wcv.bar_plot(df,max=5,sort=False)
#      30 wcv.pie(df,max=5,explode=explode)
# ---> 31 df=A.get_author_text_info(df_new,extra_StopWords,wordCloud=True)
#      32 print(df.head())
#      33 print("code ran succesfully")
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/author.py in get_author_text_info(self, df, extra_StopWords, wordCloud)
#      80
#      81   def get_author_text_info(self, df,extra_StopWords,wordCloud=False):
# ---> 82     author_buffer_details=chat.Chat().get_text_info(df,extra_StopWords,wordCloud)
#      83     return author_buffer_details
#      84
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/chat.py in get_text_info(self, df, extra_StopWords, wordCloud)
#     106       df['top5words'][df['Author']==name] = ' '.join(WordsFreqdf['Word'][0:5])#Top 5 words
#     107       df['words'][df['Author']==name] = ' '.join(WordsFreqdf['Word'][0:])#All words
# --> 108       df = Sentiment.sentiment_author(name,dstr,df)
#     109       if wordCloud== True:
#     110             #print("start ", name, " end")
#
# NameError: name 'Sentiment' is not defined

# %%
# import numpy as np
# import pandas as pd
# import nltk
# import matplotlib.pyplot as plt
# from IPython.display import set_matplotlib_formats

# %%
# add additional stop words if you want
extra_StopWords = ["thats","dont","<Media omitted>","media","Media","Omitted","omitted","also","like","https","from","all","also","and","any","are","but","can","cant","cry","due","etc","few","for","get","had","has","hasnt","have","her","here","hers","herself","him","himself","his","how","inc","into","its","ltd","may","nor","not","now","off","once","one","only","onto","our","ours","out","over","own","part","per","put","see","seem","she","than","that","the","their","them","then","thence","there","these","they","this","those","though","thus","too","top","upon","very","via","was","were","what","when","which","while","who","whoever","whom","whose","why","will","with","within","without","would","yet","you","your","yours","the"]
filepath='/Users/stlp/Downloads/WhatsApp Chat with UW MSDS Fall21.txt'

# %%
explode=[0.1,0,0.1,0.2,0.4]
text_df=wtc.load_clean_dataframe('WhatsApp Chat with Demo.txt')


#author_buffer_details=pd.DataFrame(data=A.name,columns=['Author'])
#author_buffer_details=author_buffer_details.merge(A.get_number_activeDays(text_df),on='Author',how='left')
#df_days_texted=pd.DataFrame(text_df.groupby('Author')['Date'].nunique()).rename(columns={'Date':'Days_texted'})
#df=A.get_metrics(text_df)


print(df)
wcv.bar_plot(df,max=5,sort=False)
wcv.pie(df,max=5,explode=explode)
df=A.get_author_text_info(df_new,extra_StopWords,wordCloud=True)
print(df.head())
# Out:
# Number of messages per day on whatsapp since the start date
# Empty DataFrame
# Columns: [Author, Frequency]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5c9052065175> in <module>
#      13 print(df)
#      14 wcv.bar_plot(df,max=5,sort=False)
# ---> 15 wcv.pie(df,max=5,explode=explode)
#      16 df=A.get_author_text_info(df_new,extra_StopWords,wordCloud=True)
#      17 print(df.head())
#
# ~/Downloads/WhatsApp-Chat-Analyser/WhatsappChatAnalyser/whatsapp_chat_visualizer.py in pie(df, explode, title, max, sort)
#      67     # only "explode" the 2nd slice (i.e. 'Hogs')
#      68     fig1, ax1 = plt.subplots()
# ---> 69     ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
#      70     ax1.axis('equal')  # Equal aspect ratio to ensure pie is a circle
#      71     plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3024             raise ValueError("'label' must be of length 'x'")
#    3025         if len(x) != len(explode):
# -> 3026             raise ValueError("'explode' must be of length 'x'")
#    3027         if colors is None:
#    3028             get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'
